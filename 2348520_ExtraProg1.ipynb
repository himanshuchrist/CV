# %%
import cv2
import matplotlib.pyplot as plt 
img=cv2.imread('/Users/himanshugulechha/Desktop/MSc AI&ML/Sem3/CV/Dubai_Marina_Skyline.jpg')
plt.imshow(img)

# %%
import imageio as iio
img1=iio.imread('/Users/himanshugulechha/Desktop/MSc AI&ML/Sem3/CV/Dubai_Marina_Skyline.jpg')
plt.imshow(img1)
# Out:
# /var/folders/_t/p1thpgyj6yv2d7xmn803p8tw0000gn/T/ipykernel_21371/3277369370.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img1=iio.imread('/Users/himanshugulechha/Desktop/MSc AI&ML/Sem3/CV/Dubai_Marina_Skyline.jpg')

# %%
from PIL import Image
img2=Image.open('/Users/himanshugulechha/Desktop/MSc AI&ML/Sem3/CV/Dubai_Marina_Skyline.jpg')
display(img2)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427>

# %%
img2.save("to_png.png")
img2=Image.open('/Users/himanshugulechha/Desktop/MSc AI&ML/Sem3/CV/to_png.png')
print(img2.filename)
# Out:
# /Users/himanshugulechha/Desktop/MSc AI&ML/Sem3/CV/to_png.png

# %%
img2.save("to_tif.tif")
img2=Image.open('/Users/himanshugulechha/Desktop/MSc AI&ML/Sem3/CV/to_tif.tif')
print(img2.filename)
# Out:
# /Users/himanshugulechha/Desktop/MSc AI&ML/Sem3/CV/to_tif.tif
