# %% [markdown]
# ## Frame extraction from the video and displaying the color components of the images

# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

# Loading the video
video_path = "/Users/himanshugulechha/Desktop/MSc AI&ML/Sem3/CV/video.mp4"
cam = cv2.VideoCapture(video_path)

# Getting the frame rate of the video
fps = cam.get(cv2.CAP_PROP_FPS)

# Calculating the number of frames to skip for 1 second interval
skip_frames = int(fps)  # Assuming fps is rounded to nearest integer

frame_no = 0

# Reading the frames
while (True):
    ret, frame = cam.read()
    
    if ret:
        frame_no += 1
        if frame_no % skip_frames == 0:
            # Extracting the color components
            b, g, r = cv2.split(frame)
            print(f"Frame Number: {frame_no}")
            print(f"Frame Shape: {frame.shape}")
            print(f"Color Components are as follows:\nRed - {np.mean(r):.2f}\nGreen - {np.mean(g):.2f}\nBlue - {np.mean(b):.2f}")
            plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
            plt.show()
    else:
        break

cam.release()
# Out:
# Frame Number: 30
# Frame Shape: (336, 596, 3)
# Color Components are as follows:
# Red - 58.02
# Green - 36.73
# Blue - 19.32
# Frame Number: 60
# Frame Shape: (336, 596, 3)
# Color Components are as follows:
# Red - 64.17
# Green - 16.75
# Blue - 15.63
# Frame Number: 90
# Frame Shape: (336, 596, 3)
# Color Components are as follows:
# Red - 68.81
# Green - 20.93
# Blue - 19.30
# Frame Number: 120
# Frame Shape: (336, 596, 3)
# Color Components are as follows:
# Red - 61.67
# Green - 20.73
# Blue - 21.45
# Frame Number: 150
# Frame Shape: (336, 596, 3)
# Color Components are as follows:
# Red - 46.23
# Green - 32.66
# Blue - 29.08
# Frame Number: 180
# Frame Shape: (336, 596, 3)
# Color Components are as follows:
# Red - 41.46
# Green - 20.47
# Blue - 19.98
# Frame Number: 210
# Frame Shape: (336, 596, 3)
# Color Components are as follows:
# Red - 48.72
# Green - 24.35
# Blue - 21.10
# Frame Number: 240
# Frame Shape: (336, 596, 3)
# Color Components are as follows:
# Red - 49.63
# ...
